# %% [markdown]
# # About Version Control
# What is “version control”, and why should you care? Version control is a system that records changes to a file or set of files over time so that you can recall specific versions later.
# If you are a graphic or web designer and want to keep every version of an image or layout (which you would most certainly want to), a Version Control System (VCS) is a very wise thing to use.
# **It Allows User to:**
# - Revert back files to Previous state
# - Revert back project to Previous state
# - Compare Files
# - Who Modified the Files and From where, might be causing a problem, who introduced an issue and when, and more.
#
# Using a VCS also generally means that if you screw things up or lose files, you can easily recover.
#
# Version Control System is Achieved with three approach,
#
# ### 1. Local Version Control Sytem
#
# As Before we keep our files tracking by using file system, by copying files again and again. but what if the files and folder are too big creating replicate for the same occupy space which leads to unneccessary load in drive. It is easy to forget which directory you’re in and accidentally write to the wrong file or copy over files you don’t mean to.
#
# One of the most popular VCS tools was a system called RCS (Revision Control System), which is still distributed with many computers today. RCS works by keeping differences between files in a special format on disk, it can then re-create what any file looked like at any point in time by adding up all the differences.
#
# ![image.png](attachment:83cb825a-4529-4289-b638-555dc2a3d717.png)
#
# ### 2. Centralized Version Control Sytem
#
# So, RCS or LVS approach works with local system, but it does not allow developers to work together.
# This is the another issue and mainly the need to find a better VCS so that developers, designers and etc can work together.
# To deal with this problem, Centralized Version Control Systems (CVCSs) were developed. These systems (such as CVS, Subversion, and Perforce) have a single server that contains all the versioned files, and a number of clients that check out files from that central place. For many years, this has been the standard for version control.
#
# ![image.png](attachment:9a96c141-5307-4e48-b19c-a851e6ac2123.png)
#
# ### 2. Distributed Version Control Systems
#
# This is where Distributed Version Control Systems (DVCSs) step in. In a DVCS (such as Git, Mercurial or Darcs), clients don’t just check out the latest snapshot of the files; rather, they fully mirror the repository, including its full history. Thus, if any server dies, and these systems were collaborating via that server, any of the client repositories can be copied back up to the server to restore it. Every clone is really a full backup of all the data.
#
# ![image.png](attachment:d457f15e-c2fe-4847-b326-ca1b90aa5e6c.png)

# %% [markdown]
# # What is Git ?
#
# The major difference between git and other VCS is the way the git working with its data.
# Conceptually, most other systems store information as a list of file-based changes, while git takes the snapshot at each point of time.
# These other systems (CVS, Subversion, Perforce, and so on) think of the information they store as a set of files and the changes made to each file over time (this is commonly described as delta-based version control).
#
#
# ### Other VCS
# ![image.png](attachment:f9a01d3b-ad16-4291-b923-f1c0407a895e.png)
# ### Git VCS
# ![image.png](attachment:b4239e6e-a02b-411c-8419-7b98d3b33d54.png)
#
# > Checkins over time in Other VCS.
#
# # The 3 States in Git
#
# Git has 3 States where files & folders can resides in,
#
# 1. Directory (Modified): means that you have changed the file but have not committed it to your database yet.
# 2. Staging Area (Staged): means that you have marked a modified file in its current version to go into your next commit snapshot.
# 3. Commit: means that the data is safely stored in your local database.
#
# ![image.png](attachment:72079a78-307a-4582-afbf-cf93e9ae7599.png)

# %% [markdown]
# # Installing Git
#
# 1. Installation on Linux
#
# - Fedora Based - ```$ sudo dnf install git-all```
# - Debian Based - ```$ sudo apt install git-all```
#
# 2. Installation on Mac
#
# - MacOS - ```$ git --version```
#
# 3. Windows
#
# - Download - ```https://git-scm.com/download/win```
