# %% [markdown]
# \# Distributed Git - Contributing to a Project
#
# So, We are comes a long way to work in Contribution
#
# The main difficulty with describing how to contribute to a project are the numerous variations on how to do that. Because Git is very flexible, people can and do work together in many ways, and it’s problematic to describe how you should contribute — every project is a bit different. Some of the variables involved are active contributor count, chosen workflow, your commit access, and possibly the external contribution method.
#
# 1. The first variable is active contributor count — how many users are actively contributing code to this project, and how often?
# 2. The next variable is the workflow in use for the project. Is it centralized, with each developer having equal write access to the main codeline?
# 3. The next variable is your commit access. The workflow required in order to contribute to a project is much different if you have write access to the project than if you don’t. If you don’t have write access, how does the project prefer to accept contributed work? Does it even have a policy? How much work are you contributing at a time? How often do you contribute?
#
# All these questions can affect how you contribute effectively to a project and what workflows are preferred or available to you.
#
# #### Commit Guidelines
#
# Before we can start further here’s a quick note about commit messages. Having a good guideline for creating commits and sticking to it makes working with Git and collaborating with others a lot easier.
#
# ***A commit can be as similar as a Subject in Email***
# *subject describes the email body in similar way, you commit should describe about the commit changes*
#
# ![image.png](attachment:image.png)
#
# #### Contribution Work : A Small Company Example
#
# 1. Lets, Assume you are john working on project with Jessica.
# 2. Now, to work in better collaboration the process of pull first push last approach should be followed.
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)
#
# 3. Now Jessica push her work on remote repo
#
# ![image-4.png](attachment:image-4.png)
#
# 4. So, Before you should push anything, you must pull the changes from remote so that if there is any changes so you get it, or may be some conflicts so that you resolve it before pushing.
#
# ![image-5.png](attachment:image-5.png)
#
# ![image-6.png](attachment:image-6.png)
#
# 5. At this Point the Workflow Looks like This
#
# ![image-7.png](attachment:image-7.png)
#
#
# ### Contribution Work : A Large Company Example
#
# Similar Workflow Examples for a Large Company with 3 People and 2 Repo
#
# 1. Jessica , Josie, John
# 2. server: FeatureA, serverL FeatureB
#
# ![image-8.png](attachment:image-8.png)
