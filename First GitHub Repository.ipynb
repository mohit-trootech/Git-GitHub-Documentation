# %% [markdown]
# # First Git Repository
#
# After Signup Process, Just Customize Your Profile, not mandatory but this attract the users towards your profile.
#
# go to respository section and click on new on the to create new repository, new button available at the top right corner of the main section.
#
# or, just go to this link while being signed in. [link](https://github.com/new)
#
# add basic details like name of repository, a short description of the purpose, and just create repository at the end.
#
# ![image.png](attachment:image.png)
#
# #### Interface of First Repository
#
# ![image-2.png](attachment:image-2.png)
#
# this is the interface of empty repository, we needed to add content in this repo. you can either create here or you can push local repo to github, which we talk in next module.
#
# ***Basic Details on how to host repo from local to github is provided there also***
#
# ![image-3.png](attachment:image-3.png)
#
# but the introduction includes branching and Main branch is used but we don't know branching, so lets skip and lets go to next module.
#
# > Our Head branch is Master:
#
# ![image-4.png](attachment:image-4.png)
