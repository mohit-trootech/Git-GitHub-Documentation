# %% [markdown]
# # Merge Commits
#
# Now we came a long way, Now the Work is Done Nothing is left to commit. Now Why to keep the old commits uneccesarility.
#
# 1. May be it Contains Some uneccessary code.
# 2. May be some secret.
#
# So, it is a good practice to remove old commit and make a single commit, lets say ***Deployment***.
#
# We can Acheive this with 2 Method,
#
# 1. Rebase & Squash
# 2. Reset
#
# You can use either the way both works fine.
#
# #### Merging the Branches - Rebase & Squash Approach
#
# Now First we need to understand what squash actually is ?
#
# To "squash" in Git means to combine multiple commits into one. You can do this at any point in time (by using Git's "Interactive Rebase" feature), though it is most often done when merging branches.
#
# Enough of the reading, lets take some example.
# ***better to perform all these operations in new branch***
#
# ![image.png](attachment:image.png)
#
# You can see that in this repo i have 4 commits now i wanted to make these 4 into 1.
#
# ```git rebase -i HEAD~N```
#
# ```git rebase -i COMMIT-SHA```
#
#
# ![image-6.png](attachment:image-6.png)
#
# This will open Editor
# ***This editor will open in front of you, multiple options are these you are required to choose between then.***
#
# ![image-2.png](attachment:image-2.png)
#
# You will see the pick command along with sha-abbrevet and commit message in the first line, this is the place where all things take place.
#
# ![image-3.png](attachment:image-3.png)
#
# Mutiple Commands are There:
#
# ![image-4.png](attachment:image-4.png)
#
# 1. r, reword is used to select the commit message and update that commit.
# 2. s, squash is used to remove the commit.
# 3. p, pick is used as reword but do not give option to update commit message.
# 4. d, drop is used as drop commit message in updated commit.
# 5. More Commands are also there.
#
# ![image-5.png](attachment:image-5.png)
#
# ***And Here Our Commit is Done***
#
# ![image-7.png](attachment:image-7.png)
#
# ***You can Change Commit Message***
#
# ![image-8.png](attachment:image-8.png)
#
# ***Now Lets Merge the branch with master branch***\
#
# ![image-10.png](attachment:image-10.png)
#
# ![image-9.png](attachment:image-9.png)
#
# ***Not Working huh***
# So lets try again different method
#
# ![image-11.png](attachment:image-11.png)
#
# #### Merging the branches - Reset Approach
#
# Lets, Try this again with a simple approach using reset.
# last approach write the commit messages by itself now we have to write it.
#
# ***same Repo***
#
# ![image-12.png](attachment:image-12.png)
#
# ***```git reset sha```***
#
# ![image-13.png](attachment:image-13.png)
#
# ![image-14.png](attachment:image-14.png)
#
# ***So, We are at first commit now, just add files, do changes if required and create commit***
# **You can New Commit else amend Commit**
#
# ![image-15.png](attachment:image-15.png)
#
# ![image-16.png](attachment:image-16.png)
#
# #### Pushing the branch with Updated/ Merged Commits
#
# ***It is not that easy to push this into remote again, you need to be use --force flag to update it***
#
# ![image-17.png](attachment:image-17.png)
#
# ![image-18.png](attachment:image-18.png)
#
#
# ![image-19.png](attachment:image-19.png)
