# %% [markdown]
# # About READMEs
# <!-- Boostrap Markdown File -->
# <link href="https://maxcdn.bootstrapcdn.com/bootstrap/3.3.6/css/bootstrap.min.css" rel="stylesheet" />
# <script src="https://maxcdn.bootstrapcdn.com/bootstrap/3.3.6/js/bootstrap.min.js"></script>
#
# ***You can add a README file to your repository to tell other people why your project is useful, what they can do with your project, and how they can use it.***
#
# Your respository require a way so that it can communicate to community. the way is README.md Files.
#
# A README is often the first item a visitor will see when visiting your repository. README files typically include information on:
#
# - What the project does
# - Why the project is useful
# - How users can get started with the project
# - Where users can get help with your project
# - Who maintains and contributes to the project
#
# [docs](https://docs.github.com/en/repositories/managing-your-repositorys-settings-and-features/customizing-your-repository/about-readmes)
#
# #### Lets Create Our Own README File
#
# 1. go to github repo, and just create a new readme file
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# You can Commit the File in Github.
#
# ***readme.md files have its own syntax for writing link***
# *maybe later you see the repo readme.md will be updated*
#
# # Adding a license to a repository
#
# ***You can include an open source license in your repository to make it easier for other people to contribute.***
#
# If you include a detectable license in your repository, people who visit your repository will see it at the top of the repository page. To read the entire license file, click the license name.
#
# ![image-3.png](attachment:image-3.png)
#
# 1. On GitHub.com, navigate to the main page of the repository.
# 2. Above the list of files, select the Add file  dropdown menu, then click  Create new file.
#
# ![image-4.png](attachment:image-4.png)
#
# 3. In the file name field, type LICENSE or LICENSE.md (with all caps).
# 4. Under the file name, click Choose a license template.
#
# ![image-5.png](attachment:image-5.png)
#
# 5. On the left side of the page, under "Add a license to your project," review the available licenses, then select a license from the list.
#
# ![image-6.png](attachment:image-6.png)
#
# ![image-7.png](attachment:image-7.png)
#
# 6. Click Review and submit.
# 7. Click Commit changes...
#
# ![image-8.png](attachment:image-8.png)
#
# #### Introduction to Fetch and Pull
#
# Now Lets type ```git status``` in local git cli
#
# ![image-9.png](attachment:image-9.png)
#
#
# No Error, So lets Push the Changes.
#
# ![image-10.png](attachment:image-10.png)
#
# Error !!!, Why this error because the local repo is not at same HEAD with remote repo. Because we recently added a README and LICENSE File.
#
# Here Comes the concept of Fetch and Pull, *which we talk in later module*
